# %%
# !pip install google-play-scraper pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.5 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import Sort, reviews
import pandas as pd
import matplotlib.pyplot as plt

# %%
app_id = "com.traveloka.android"

result, _ = reviews(
    app_id,
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=10000
)

print(f"Jumlah ulasan yang diambil: {len(result)}")

df = pd.DataFrame(result)

display(df.head())
# Out:
# Jumlah ulasan yang diambil: 10000
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                                reviewId         userName  \
# 0  3850438f-ac3a-4431-9345-b7e353e4f087  Pengguna Google
# 1  bc613bed-e8e9-4590-90c1-a68fc71679c6  Pengguna Google
# 2  70b9f9e2-1199-48d7-9dd3-785759471b83  Pengguna Google
# 3  29717515-fd96-4ec1-b85d-97cd3230f5e8  Pengguna Google
# ...

# %%
df = df[['userName', 'content', 'score', 'at', 'replyContent']]

df['date'] = df['at'].dt.date
df['time'] = df['at'].dt.time

display(df.head())
# Out:
#           userName                                            content  score  \
# 0  Pengguna Google            tiap buka apk minta update mulu ya elah      2
# 1  Pengguna Google                                               bgus      5
# 2  Pengguna Google  secara umum pesan di agoda cukup menyenangkan,...      3
# 3  Pengguna Google                                       bagus sekali      5
# 4  Pengguna Google                                             mantap      5
#
#                    at                                       replyContent  \
# 0 2025-10-14 00:08:33  Hai Rasyid, mohon maaf atas ketidaknyamanan ya...
# 1 2025-10-13 21:14:20  Hello! Thank you very much for the positive re...
# 2 2025-10-13 17:00:19  Hai Irvan, senang mendengar Anda menyukai apli...
# 3 2025-10-13 16:53:33  Halo Kak, terima kasih banyak atas ratingnya. ...
# 4 2025-10-13 15:47:16  Halo Kak, terima kasih banyak atas ratingnya. ...
#
#          date      time
# 0  2025-10-14  00:08:33
# ...

# %%
df.to_csv("traveloka_reviews.csv", index=False, encoding='utf-8-sig')
print("Data berhasil disimpan")
# Out:
# Data berhasil disimpan
